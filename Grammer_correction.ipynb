# %% [markdown]
# Using Gramformer from github repository library

# %%
# !pip3 install -U git+https://github.com/PrithivirajDamodaran/Gramformer.git

# %%
# !pip install happytransformer

# %%
from happytransformer import HappyTextToText

# %%
happy_tt = HappyTextToText("T5",  "prithivida/grammar_error_correcter_v1")
# Out:
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]

# %%
text = "gec: " + "We no open, sorrry"

# %%
from happytransformer import TTSettings

# %%
TTSettings(do_sample=True, top_k=50, temperature=0.7, max_length=20)
# Out:
# TTSettings(min_length=10, max_length=20, do_sample=True, early_stopping=False, num_beams=1, temperature=0.7, top_k=50, no_repeat_ngram_size=0, top_p=1)

# %%
from happytransformer import HappyTextToText
from happytransformer import TTSettings

happy_tt = HappyTextToText("T5", "prithivida/grammar_error_correcter_v1")

text = "gec: " + "It is not of only your business"
settings = TTSettings(do_sample=True, top_k=10, temperature=0.5,  min_length=1, max_length=100)
result = happy_tt.generate_text(text, args=settings)

print(result.text)
# Out:
# It is not about your business.

# %%
from happytransformer import HappyTextToText
from happytransformer import TTSettings

happy_tt = HappyTextToText("T5", "prithivida/grammar_error_correcter_v1")

text = "gec: " + "She see Tom is catched by policeman in park at last night"
settings = TTSettings(do_sample=True, top_k=10, temperature=0.5,  min_length=1, max_length=100)
result = happy_tt.generate_text(text, args=settings)

print(result.text)
# Out:
# She sees Tom being catched by a policeman in park last night.
